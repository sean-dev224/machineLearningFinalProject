# %% [markdown]
# ***This file contains code to generate visualizations of data***

# %%
import numpy as np
import pandas as pd
import seaborn

# %%
health_data = pd.read_csv("health_lifestyle_dataset.csv", nrows=1000)
health_data
# Out:
#      id  age  gender   bmi  daily_steps  sleep_hours  water_intake_l  \
# 0     1   56    Male  20.5         4198          3.9             3.4
# 1     2   69  Female  33.3        14359          9.0             4.7
# 2     3   46    Male  31.6         1817          6.6             4.2
# 3     4   32  Female  38.2        15772          3.6             2.0
# 4     5   60  Female  33.6         6037          3.8             4.0
# ..  ...  ...     ...   ...          ...          ...             ...
# 95   96   46    Male  20.4         5680          9.7             0.7
# 96   97   35    Male  29.0         5461          4.3             0.9
# 97   98   43    Male  25.1         6802          9.3             3.5
# 98   99   61    Male  37.8        10913          8.8             1.0
# 99  100   51    Male  18.8         9349          8.3             4.0
#
#     calories_consumed  smoker  alcohol  resting_hr  systolic_bp  diastolic_bp  \
# ...

# %%
seaborn.pairplot(health_data, hue="disease_risk")
